# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import geopandas as gpd

# %%
chinaBorder = gpd.read_file("./CMADS/中国轮廓/国界/bou1_4l.shp")

# %%
chinaBorder
# Out:
#       FNODE_  TNODE_  LPOLY_  RPOLY_  LENGTH  BOU1_4M_  BOU1_4M_ID  GBCODE  \
# 0        929     928       1     197   0.525         1         369   61010
# 1        928     930       1     197   5.179         2         321   61010
# 2        931     929       1     197   2.159         3        1001   61010
# 3        930     932       1     197   2.341         4         337   61010
# 4        933     931       1     197   2.063         5        1001   61010
# ...      ...     ...     ...     ...     ...       ...         ...     ...
# 1377     918     919       1       1   0.045      1378           1   26100
# 1378     920     921       1       1   0.071      1379           2   26100
# 1379     922     923       1       1   0.055      1380           3   26100
# 1380     924     925       1       1   0.052      1381           1   26100
# 1381     926     927       1       1   1.112      1382        1001   61010
#
#                                                geometry
# 0     LINESTRING (121.00548 53.28751, 121.00812 53.2...
# 1     LINESTRING (121.48844 53.33265, 121.49954 53.3...
# 2     LINESTRING (120.64791 52.56527, 120.64351 52.5...
# 3     LINESTRING (125.72549 52.87209, 125.73853 52.8...
# 4     LINESTRING (119.97117 51.48934, 119.97012 51.4...
# ...                                                 ...
# 1377  LINESTRING (112.64270 5.38615, 112.64041 5.385...
# 1378  LINESTRING (112.28411 3.97788, 112.28306 3.979...
# 1379  LINESTRING (112.29087 3.88075, 112.29078 3.882...
# 1380  LINESTRING (112.06014 3.86478, 112.05986 3.866...
# 1381  LINESTRING (111.79456 3.40848, 111.85775 3.422...
#
# [1382 rows x 9 columns]

# %%
chinaBorder.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
cmadsShape = gpd.read_file("./CMADS/CMADSV1.1_station/CMADS-area.shp")
cmadsShape.plot()
# Out:
# <AxesSubplot:>

# %%
max_longitude = 135
min_longitude = 73
max_latitude = 54
min_latitude = 18

# %%
cmadsShape2 = gpd.read_file("./CMADS/CMADSV1.1_station/CMADS1.1.shp")
cmadsShape2

# select 73-135 E, 18-54 N
# cmadsShape2 = cmadsShape2[(cmadsShape2["Longitude"]>70) & (cmadsShape2["Longitude"]<135) & (cmadsShape2["Latitude"]>15) & (cmadsShape2["Latitude"]<55)]

# %%
cmadsShape2R = cmadsShape2[(cmadsShape2["Longitude"]>min_longitude) & (cmadsShape2["Longitude"]<max_longitude) & (cmadsShape2["Latitude"]>min_latitude) & (cmadsShape2["Latitude"]<max_latitude)]

# %%
# randomly sample 1000, set point size to 0.1

# only plot select 73-135 E, 18-54 N
fix, ax = plt.subplots(figsize=(10,10))

cmadsShape2.sample(1000).plot(ax=ax, markersize=0.1)
chinaBorder.plot(ax=ax, edgecolor='black', facecolor='none', linewidth=0.5)

ax.set_xlim(min_longitude, max_longitude)
ax.set_ylim(min_latitude, max_latitude)
# Out:
# (18.0, 54.0)
